# %% [markdown]
# # Practical_2: String and files

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 1:
# Create a string variable `text` and assign it the value `"Python is amazing!"`.
#
# ```python
# # Exercise 1
# ```

# %%
text="Python is amazing!"
text
# Out:
# 'Python is amazing!'

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 2:
# Find the length of the string `"Hello, World!"` and store it in a variable `length`.
#
# ```python
# # Exercise 2
# ```

# %%
length="Hello, World!"
len(length)
# Out:
# 13

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 3:
# Convert the string `"python programming"` to uppercase and store it in a variable `upper_text`.
#
# ```python
# # Exercise 3
# ```

# %%
upper_text="python programming"
upper_text.upper()
# Out:
# 'PYTHON PROGRAMMING'

# %% [markdown]
# ---
#
# ### Exercise 4:
# Extract the first 5 characters from the string `"Artificial Intelligence"`.
#
# ```python
# # Exercise 4
# ```
#
# ---

# %%
touch='Artificial Intelligence'
touch[1:6]
# Out:
# 'rtifi'

# %% [markdown]
# ### Exercise 5:
# Concatenate the strings `"Hello"` and `"World"` with a space in between.
#
# ```python
# # Exercise 5
# ```

# %%
concat="Hello" + "  " + "World"
concat
# Out:
# 'Hello  World'

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 6:
# Replace the word `"dog"` with `"cat"` in the string `"The quick brown dog jumps over the lazy dog."`.
#
# ```python
# # Exercise 6
# ```

# %%
word= "The quick brown dog jumps over the lazy dog."
new=word.replace("dog","cat")
new
# Out:
# 'The quick brown cat jumps over the lazy cat.'

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 7:
# Split the string `"apple,banana,orange"` by commas and store the result in a list `fruits_list`.
#
# ```python
# # Exercise 7
# ```

# %%
string="apple,banana,orange"
coma=string.replace(",",".")
coma
# Out:
# 'apple.banana.orange'

# %%
coma = "apple.banana.orange"

mot = ""
liste = []

for k in coma:
    if k != ".":
        mot += k
    else:
        liste.append(mot)
        mot = ""  
liste.append(mot)

print(liste)
# Out:
# ['apple', 'banana', 'orange']

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 8:
# Use string formatting to create the sentence `"My name is Alice and I am 25 years old."`, where the name and age are variables.
#
# ```python
# # Exercise 8
# ```

# %%
age=25
name=alice
Print(f"My {name} is Alice and I am {age} years old.")

# %% [markdown]
# ---
#
# ### Exercise 9:
# Check if the string `"python"` is present in the sentence `"I love python programming"`.
#
# ```python
# # Exercise 9
# ```

# %%
sentence="I love python programming"
if "python"  in sentence :
    print("true")
else :
    print("false ")
# Out:
# true

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 10:
# Count the number of occurrences of the letter `"e"` in the string `"Elephant is an elegant animal"`.
#
# ```python
# # Exercise 10
# ```

# %%
sentense2="Elephant is an elegant animal"
count=0
for i in sentense2:
    for k in sentence2:
        if k=="e":
            count +=1
print(f"e is represented in {entense2}:{count} times ")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 4
#       2 count=0
#       3 for i in sentense2:
# ----> 4     for k in sentence2:
#       5         if k=="e":
#       6             count +=1
#
# NameError: name 'sentence2' is not defined

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 11:
# Remove any leading and trailing spaces from the string `"   Data Science   "`.
#
# ```python
# # Exercise 11
# ```

# %%
strin2= "   Data Science   "
voy=strin2.strip()
voy
# Out:
# 'Data Science'

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 12:
# Convert the string `"100"` into an integer and store it in a variable `int_value`.
#
# ```python
# # Exercise 12
# ```

# %%
strin="100"

trans=int(strin)
trans
# Out:
# 100

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 13:
# Extract the substring `"pro"` from the string `"programming"`.
#
# ```python
# # Exercise 13
# ```

# %%
trin3="programming"
mot="pro"
trin3.replace(mot," ")
# Out:
# ' gramming'

# %% [markdown]
# ---
#
# ### Exercise 14:
# Check if the string `"data"` starts with `"da"` and ends with `"ta"`.
#
# ```python
# # Exercise 14
# ```

# %%
striny="data"
if striny[:2]=="da" and striny[-3]== "ta":
    print("true")
else:
    print("false")
# Out:
# false

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 15:
# Reverse the string `"machine learning"` and store the result in `reversed_text`.
#
# ```python
# # Exercise 15
# ```

# %%
strin4="machine learning"
reversed_text= strin4[::-1]

reversed_text
# Out:
# 'gninrael enihcam'

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 16:
# Convert the first letter of each word in the string `"machine learning is fun"` to uppercase.
#
# ```python
# # Exercise 16
# ```

# %%
string3= "machine learning is fun"
string3.capitalize()
# Out:
# 'Machine learning is fun'

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 17:
# Create a multiline string representing a poem and store it in a variable `poem`.
#
# ```python
# # Exercise 17
# ```

# %%
multiline= """This is a multiline string.
It can contain multiple lines of text.
All line breaks and indentation within the triple quotes are preserved."""
ad="poem"
print(f"{multiline} and the word {ad} is added in the text")
#print(multiline)
# Out:
# This is a multiline string.
# It can contain multiple lines of text.
# All line breaks and indentation within the triple quotes are preserved. and the word poem is added in the text

# %% [markdown]
# ---
#
# ### Exercise 18:
# Write a string to a file named `"output.txt"`.
#
# ```python
# # Exercise 18
# ```

# %%
with open  file("output.txt","w")as f
       f.write()

# %% [markdown]
# ---
#
# ### Exercise 19:
# Read the contents of a file named `"data.txt"` and print it line by line.
#
# ```python
# # Exercise 19

# %% [markdown]
# ### Exercise 20:
# Check if a file `"example.txt"` exists before opening it.
#
# ```python
# # Exercise 20
# ```

# %% [markdown]
# ---
#
# ### Exercise 21:
# Append a new line `"This is a new line"` to an existing file `"notes.txt"`.
#
# ```python
# # Exercise 21
# ```
#
# ---
#
# ### Exercise 22:
# Read the contents of a file `"log.txt"` and store each line in a list `log_lines`.
#
# ```python
# # Exercise 22
# ```
#
# ---
#
# ### Exercise 23:
# Create a new file `"report.txt"` and write the string `"Data analysis report"` to it.
#
# ```python
# # Exercise 23
# ```
#
# ---
#
# ### Exercise 24:
# Replace the word `"error"` with `"issue"` in a file `"log.txt"`.
#
# ```python
# # Exercise 24
# ```
#
# ---
#
# ### Exercise 25:
# Count the number of words in a text file `"document.txt"`.
#
# ```python
# # Exercise 25
# ```
#
# ---
#
# ### Exercise 26:
# Write a Python script that reads a file `"essay.txt"` and prints the total number of lines, words, and characters.
#
# ```python
# # Exercise 26
# ```
#
# ---
#
# ### Exercise 27:
# Copy the contents of one file `"source.txt"` to another file `"destination.txt"`.
#
# ```python
# # Exercise 27
# ```
#
# ---
#
# ### Exercise 28:
# Write a Python function that takes a filename as input and returns the number of lines in the file.
#
# ```python
# # Exercise 28
# ```
#
# ---
#
# ### Exercise 29:
# Extract all the words from a text file `"article.txt"` that contain more than 5 characters.
#
# ```python
# # Exercise 29
# ```
#
# ---
#
# ### Exercise 30:
# Convert the contents of a file `"notes.txt"` to uppercase and save the result in another file `"uppercase_notes.txt"`.
#
# ```python
# # Exercise 30
# ```
#
# ---
#
# ### Exercise 31:
# Write a Python script that reads a file and removes all empty lines.
#
# ```python
# # Exercise 31
# ```
#
# ---
#
# ### Exercise 32:
# Open a file `"config.txt"` in both read and write mode.
#
# ```python
# # Exercise 32
# ```
#
# ---
#
# ### Exercise 33:
# Write a Python function that reads a file and prints the longest line in the file.
#
# ```python
# # Exercise 33
# ```
#
# ---
#
# ### Exercise 34:
# Write a Python script to count the frequency of each letter in a text file `"message.txt"`.
#
# ```python
# # Exercise 34
# ```
#
# ---
#
# ### Exercise 35:
# Write a Python script that reads a file and prints the total number of characters, excluding spaces.
#
# ```python
# # Exercise 35
# ```
#
# ---
#
# ### Exercise 36:
# Create a Python script to check whether a file is empty or not.
#
# ```python
# # Exercise 36
# ```
#
# ---
#
# ### Exercise 37:
# Write a Python function that reads a file and removes all punctuation marks from the text.
#
# ```python
# # Exercise 37
# ```
#
# ---
#
# ### Exercise 38:
# Create a Python function that writes a list of strings to a file, each string on a new line.
#
# ```python
# # Exercise 38
# ```
#
# ---
#
# ### Exercise 39:
# Write a Python script to count the number of lines that start with a specific letter (e.g., "A") in a text file.
#
# ```python
# # Exercise 39
# ```
#
# ---
#
# ### Exercise 40:
# Write a Python function that takes a string as input and writes it to a file `"output.txt"` in reverse order.
#
# ```python
# # Exercise 40
# ```
#
# ---
#
# ### Exercise 41:
# Write a Python script that reads a file and prints all the lines that contain the word `"Python"`.
#
# ```python
# # Exercise 41
# ```

# %% [markdown]
# ---
#
# ### Exercise 42:
# Write a Python script that opens a file and removes all numeric digits from the file's content.
#
# ```python
# # Exercise 42
# ```

# %% [markdown]
# ---
#
# ### Exercise 43:
# Write a Python script to find the most frequent word in a text file `"book.txt"`.
#
# ```python
# # Exercise 43
# ```
#
# ---
#
# ### Exercise 44:
# Write a Python script that reads a file and prints all the lines that contain exactly 5 words.
#
# ```python
# # Exercise 44
# ```
#
# ---
#
# ### Exercise 45:
# Write a Python script to read a file and print the first and last line of the file.
#
# ```python
# # Exercise 45
# ```
#
# ---
#
# ### Exercise 46:
# Write a Python script that checks if a file `"students.txt"` is writable.
#
# ```python
# # Exercise 46
# ```
#
# ---
#
# ### Exercise 47:
# Create a Python function that opens a file and returns the number of unique words in the file.
#
# ```python
# # Exercise 47
# ```
#
# ---

# %%
with open("file.txt","r")as f:
    container=f.read()
    for line in container :
        print(line)
    f.close()

# %% [markdown]
# ### Exercise 48:
# Write a Python script that reads a file and prints all lines in reverse order.
#
# ```python
# # Exercise 48
# ```
#
# ---

# %%
with open("sortu.txt", "r" )as file:
    container=file.read()
    print (container)
nouveau=container.reverse()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[133], line 1
# ----> 1 with open("sortu.txt", "r" )as file:
#       2     container=file.read()
#       3     print (container)
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sortu.txt'

# %% [markdown]
# _
# ---

# %% [markdown]
# ### Exercise 50:
# Write a Python script that reads a file and replaces every occurrence of `"Python"` with `"Java"`.
#
# ```python
# # Exercise 50
# ```
#
# ---

# %%
with open("inscrit.txt", "r")as f :
 
    content=f.read()
    
    content.replace("Python","Java")
    f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 with open("inscrit.txt", "r")as f :
#       3     content=f.read()
#       5     content.replace("Python","Java")
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'inscrit.txt'
